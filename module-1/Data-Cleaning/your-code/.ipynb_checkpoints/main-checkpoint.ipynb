# %% [markdown]
# # Data Cleaning
#
# #### 1. Import pandas library.

# %%
import pandas as pd
import os

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data.

# %%
import pymysql
from sqlalchemy import create_engine
os.getcwd()
# Out:
# '/Users/victorrobert-faille/Documents/Ironhack/dataV2-labs/module-1/Data-Cleaning/your-code'

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/dataset/Stats).

# %% [markdown]
# hostname: relational.fit.cvut.cz
# port: 3306
# username: guest
# password: relational

# %%
# ?create_engine

# %%
engine=create_engine("""mysql+pymysql://guest:relational@relational.fit.cvut.cz/stats""")

# %% [markdown]
# #### 4. Import the users table.

# %%
df_import_users = pd.read_sql_query("SELECT * from stats.users",engine)
df_import_users
# Out:
#           Id  Reputation        CreationDate     DisplayName  \
# 0         -1           1 2010-07-19 06:55:26       Community
# 1          2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2          3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3          4         101 2010-07-19 19:03:27          Emmett
# 4          5        6792 2010-07-19 19:03:57           Shane
# ...      ...         ...                 ...             ...
# 40320  55743           1 2014-09-13 21:03:50       AussieMeg
# 40321  55744           6 2014-09-13 21:39:30       Mia Maria
# 40322  55745         101 2014-09-13 23:45:27    tronbabylove
# 40323  55746         106 2014-09-14 00:29:41             GPP
# 40324  55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 5. Rename Id column to userId.

# %%
df_import_users.rename(columns = {"Id":"UserID"} , inplace = True)
df_import_users
# Out:
#        UserID  Reputation        CreationDate     DisplayName  \
# 0          -1           1 2010-07-19 06:55:26       Community
# 1           2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2           3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3           4         101 2010-07-19 19:03:27          Emmett
# 4           5        6792 2010-07-19 19:03:57           Shane
# ...       ...         ...                 ...             ...
# 40320   55743           1 2014-09-13 21:03:50       AussieMeg
# 40321   55744           6 2014-09-13 21:39:30       Mia Maria
# 40322   55745         101 2014-09-13 23:45:27    tronbabylove
# 40323   55746         106 2014-09-14 00:29:41             GPP
# 40324   55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
df_import_posts = pd.read_sql_query("SELECT * from stats.posts",engine)

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId.

# %%
df_import_posts.rename(columns = {"Id":"postId", "OwnerUserId":"UserID"} , inplace = True)
df_import_posts
# Out:
#        postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# ...       ...         ...               ...                 ...    ...
# 91971  115374           2               NaN 2014-09-13 23:45:39      2
# 91972  115375           1               NaN 2014-09-13 23:46:05      0
# 91973  115376           1               NaN 2014-09-14 01:27:54      1
# 91974  115377           2               NaN 2014-09-14 02:03:28      0
# 91975  115378           2               NaN 2014-09-14 02:09:23      0
#
#        ViewCount                                               Body   UserID  \
# ...

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
# **users columns**: userId, Reputation, Views, UpVotes, DownVotes
# **posts columns**: postId, Score, userID, ViewCount, CommentCount

# %%
users = df_import_users[["UserID","Reputation","Views","UpVotes","DownVotes"]]
posts = df_import_posts[["postId","Score","UserID","ViewCount","CommentCount"]]

# %% [markdown]
# #### 9. Merge the new dataframes you have created, of users and posts.
# You will need to make an inner [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
merged = users.merge(posts, how="inner", on = "UserID")

# %% [markdown]
# #### 10. How many missing values do you have in your merged dataframe? On which columns?

# %%
(merged.isna().sum()/merged.shape[0])*100
# Out:
# UserID           0.000000
# Reputation       0.000000
# Views            0.000000
# UpVotes          0.000000
# DownVotes        0.000000
# postId           0.000000
# Score            0.000000
# ViewCount       53.426654
# CommentCount     0.000000
# dtype: float64

# %% [markdown]
# #### 11. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before going to the next step.

# %%
merged.ViewCount
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 90579    16.0
# 90580    40.0
# 90581    17.0
# 90582    13.0
# 90583     5.0
# Name: ViewCount, Length: 90584, dtype: float64

# %% [markdown]
# #### 12. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
merged.sample(3)
# Out:
#        UserID  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 58249   20099         106      1        0          0   48558      1
# 73759   31477          74      7        0          0   73123      2
# 81269   41023           6      2        0          0   94848      0
#
#        ViewCount  CommentCount
# 58249       77.0             4
# 73759      168.0             2
# 81269       32.0             0

# %%
merged[merged.ViewCount>0].sample(3)
# Out:
#        UserID  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 14013    1124        3000    456      140          7   10943     28
# 77290   36130         158      6        4          0   81158      1
# 85004   45018           8      1        0          0   96525      1
#
#        ViewCount  CommentCount
# 14013     1180.0             4
# 77290       76.0             7
# 85004       57.0             0

# %%
merged[merged.ViewCount.isna()].sample(3)
# Out:
#        UserID  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 2384      183       22625   4069     2496         45   13790      1
# 45277   11032       22275   7395     2619         42   38319      1
# 2363      183       22625   4069     2496         45   12591      4
#
#        ViewCount  CommentCount
# 2384         NaN             4
# 45277        NaN             2
# 2363         NaN             0

# %%
merged[merged.ViewCount.isna()].UserID.nunique()
# Out:
# 5959

# %%
merged[merged.ViewCount.isna()].UserID.value_counts()
# Out:
# 805      1712
# 686      1567
# 919      1200
# 11032     954
# 7290      821
#          ...
# 24833       1
# 37119       1
# 41209       1
# 27574       1
# 25622       1
# Name: UserID, Length: 5959, dtype: int64

# %%
merged[merged.ViewCount.isna()].UserID
# Out:
# 0           -1
# 1           -1
# 2           -1
# 3           -1
# 4           -1
#          ...
# 90518    55605
# 90521    55609
# 90528    55621
# 90536    55637
# 90575    55729
# Name: UserID, Length: 48396, dtype: int64

# %%
merged[merged.UserID==-1]
# Out:
#      UserID  Reputation  Views  UpVotes  DownVotes  postId  Score  ViewCount  \
# 0        -1           1      0     5007       1920    2175      0        NaN
# 1        -1           1      0     5007       1920    8576      0        NaN
# 2        -1           1      0     5007       1920    8578      0        NaN
# 3        -1           1      0     5007       1920    8981      0        NaN
# 4        -1           1      0     5007       1920    8982      0        NaN
# ..      ...         ...    ...      ...        ...     ...    ...        ...
# 206      -1           1      0     5007       1920  107658      0        NaN
# 207      -1           1      0     5007       1920  109441      0        NaN
# 208      -1           1      0     5007       1920  112068      0        NaN
# 209      -1           1      0     5007       1920  112070      0        NaN
# 210      -1           1      0     5007       1920  112517      0        NaN
#
#      CommentCount
# 0               0
# ...

# %%
merged.drop(merged[merged.UserID==-1].index, inplace = True)

# %%
merged[merged.ViewCount.isna()].UserID.value_counts()
# Out:
# 805      1712
# 686      1567
# 919      1200
# 11032     954
# 7290      821
#          ...
# 9001        1
# 32504       1
# 31522       1
# 30489       1
# 35515       1
# Name: UserID, Length: 5958, dtype: int64

# %%
merged[merged.UserID==805]
# Out:
#        UserID  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 8724      805       65272   5680     7035        143    1425     11
# 8725      805       65272   5680     7035        143    1723      8
# 8726      805       65272   5680     7035        143    1724      5
# 8727      805       65272   5680     7035        143    2434      2
# 8728      805       65272   5680     7035        143    2589      2
# ...       ...         ...    ...      ...        ...     ...    ...
# 10439     805       65272   5680     7035        143  115332      1
# 10440     805       65272   5680     7035        143  115337      1
# 10441     805       65272   5680     7035        143  115354      2
# 10442     805       65272   5680     7035        143  115374      2
# 10443     805       65272   5680     7035        143  115377      0
#
#        ViewCount  CommentCount
# 8724         NaN             3
# 8725         NaN             4
# 8726         NaN             0
# ...

# %%
merged[merged.ViewCount.isna()].UserID.value_counts()
# Out:
# 805      1712
# 686      1567
# 919      1200
# 11032     954
# 7290      821
#          ...
# 9001        1
# 32504       1
# 31522       1
# 30489       1
# 35515       1
# Name: UserID, Length: 5958, dtype: int64

# %% [markdown]
# Dummies

# %%
merged["was_missing"]=merged.ViewCount.isna().astype(int)

# %%
merged.ViewCount.hist(bins = 100)

# %%
merged.ViewCount=merged.ViewCount.fillna(0)

# %%
merged.head()
# Out:
#      UserID  Reputation  Views  UpVotes  DownVotes  postId  Score  ViewCount  \
# 211       5        6792   1145      662          5       6    152    29229.0
# 212       5        6792   1145      662          5      12     20        0.0
# 213       5        6792   1145      662          5      32     12        0.0
# 214       5        6792   1145      662          5      49      6        0.0
# 215       5        6792   1145      662          5      64      6        0.0
#
#      CommentCount  was_missing
# 211             5            0
# 212             1            1
# 213             0            1
# 214             0            1
# 215             0            1

# %%
merged.ViewCount.hist(bins = 100)

# %%
merged.isna().sum().sum()
# Out:
# 0

# %%
merged.ViewCount = merged.ViewCount.astype(int)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90373 entries, 211 to 90583
# Data columns (total 10 columns):
# UserID          90373 non-null int64
# Reputation      90373 non-null int64
# Views           90373 non-null int64
# UpVotes         90373 non-null int64
# DownVotes       90373 non-null int64
# postId          90373 non-null int64
# Score           90373 non-null int64
# ViewCount       90373 non-null int64
# CommentCount    90373 non-null int64
# was_missing     90373 non-null int64
# dtypes: int64(10)
# memory usage: 7.6 MB
